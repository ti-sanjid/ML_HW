# %%
import  xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import warnings
import math

# %% [markdown]
# # t2m

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.t2m.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature/t2m csv files/t2m.{filename[12:-3]}.csv',index=False)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature/t2m csv files/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
t2m_df = pd.concat(dfs, ignore_index=True)
# t2m_df=t2m_df.drop('Unnamed: 0', axis=1)

t2m_df
# csv_files
# Out:
#               time  latitude  longitude        t2m
# 0       1981-03-01     26.00      88.50  300.10745
# 1       1981-03-01     26.00      89.75  300.12964
# 2       1981-03-01     26.00      91.00  300.21990
# 3       1981-03-01     26.00      92.25  298.27060
# 4       1981-03-01     24.75      88.50  298.44992
# ...            ...       ...        ...        ...
# 205795  2022-10-31     22.25      92.25  301.38754
# 205796  2022-10-31     21.00      88.50  301.09260
# 205797  2022-10-31     21.00      89.75  300.95898
# 205798  2022-10-31     21.00      91.00  301.19010
# 205799  2022-10-31     21.00      92.25  301.51074
#
# [205800 rows x 4 columns]

# %% [markdown]
# # mx2t

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily_max = ds.mx2t.resample(time='D').max() #change 
        ds_daily = ds_daily_max.sel(time=(ds_daily_max['time.month'] >= 3) & (ds_daily_max['time.month'] <= 10))
        
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature/mxt csv files/mx2t.{filename[12:-3]}.csv',index=False)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature/mxt csv files/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
mx2t_df = pd.concat(dfs, ignore_index=True)


mx2t_df
# csv_files
# Out:
#               time  latitude  longitude       mx2t
# 0       1981-03-01     26.00      88.50  306.62286
# 1       1981-03-01     26.00      89.75  306.91562
# 2       1981-03-01     26.00      91.00  304.94385
# 3       1981-03-01     26.00      92.25  303.35596
# 4       1981-03-01     24.75      88.50  306.27887
# ...            ...       ...        ...        ...
# 205795  2022-10-31     22.25      92.25  304.44520
# 205796  2022-10-31     21.00      88.50  301.87408
# 205797  2022-10-31     21.00      89.75  301.36470
# 205798  2022-10-31     21.00      91.00  301.56662
# 205799  2022-10-31     21.00      92.25  303.90482
#
# [205800 rows x 4 columns]

# %% [markdown]
# # mn2t

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily_min = ds.mn2t.resample(time='D').min() #change 
        ds_daily = ds_daily_min.sel(time=(ds_daily_min['time.month'] >= 3) & (ds_daily_min['time.month'] <= 10))
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature/mnt csv files/mx2t.{filename[12:-3]}.csv',index=False)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Era5 Temperature/mnt csv files/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
mn2t_df = pd.concat(dfs, ignore_index=True)


mn2t_df
# csv_files
# Out:
#               time  latitude  longitude       mn2t
# 0       1981-03-01     26.00      88.50  292.43830
# 1       1981-03-01     26.00      89.75  292.82672
# 2       1981-03-01     26.00      91.00  294.69223
# 3       1981-03-01     26.00      92.25  292.18810
# 4       1981-03-01     24.75      88.50  292.41772
# ...            ...       ...        ...        ...
# 205795  2022-10-31     22.25      92.25  296.35650
# 205796  2022-10-31     21.00      88.50  300.35898
# 205797  2022-10-31     21.00      89.75  300.61063
# 205798  2022-10-31     21.00      91.00  300.68450
# 205799  2022-10-31     21.00      92.25  298.59036
#
# [205800 rows x 4 columns]

# %% [markdown]
# # 10u

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/u_v_prcep.1981.nc')

# %%
ds.tp
# Out:
# <xarray.DataArray 'tp' (time: 8760, latitude: 33, longitude: 29)>
# [8383320 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Attributes:
#     units:      m
#     long_name:  Total precipitation

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.u10.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/10 u csv/u10.{filename[10:-3]}.csv',index=False)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/10 u csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
u10_df = pd.concat(dfs, ignore_index=True)


u10_df
# csv_files
# Out:
#               time  latitude  longitude       u10
# 0       1981-03-01     26.00      88.50  4.935639
# 1       1981-03-01     26.00      89.75  3.125891
# 2       1981-03-01     26.00      91.00  3.617355
# 3       1981-03-01     26.00      92.25  3.407431
# 4       1981-03-01     24.75      88.50  1.543232
# ...            ...       ...        ...       ...
# 205795  2022-10-31     22.25      92.25  0.186298
# 205796  2022-10-31     21.00      88.50 -0.896101
# 205797  2022-10-31     21.00      89.75 -0.123198
# 205798  2022-10-31     21.00      91.00  0.690809
# 205799  2022-10-31     21.00      92.25  0.500116
#
# [205800 rows x 4 columns]

# %% [markdown]
# # 10v

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.v10.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/10 v csv/v10.{filename[10:-3]}.csv',index=False)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/10 v csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
v10_df = pd.concat(dfs, ignore_index=True)


v10_df
# csv_files
# Out:
#               time  latitude  longitude       v10
# 0       1981-03-01     26.00      88.50  0.746331
# 1       1981-03-01     26.00      89.75  3.137681
# 2       1981-03-01     26.00      91.00  3.682035
# 3       1981-03-01     26.00      92.25  2.158481
# 4       1981-03-01     24.75      88.50  0.937359
# ...            ...       ...        ...       ...
# 205795  2022-10-31     22.25      92.25 -0.946570
# 205796  2022-10-31     21.00      88.50 -4.201827
# 205797  2022-10-31     21.00      89.75 -3.573307
# 205798  2022-10-31     21.00      91.00 -4.013993
# 205799  2022-10-31     21.00      92.25 -2.048487
#
# [205800 rows x 4 columns]

# %% [markdown]
# # Wind Speed

# %%
merged_df = pd.merge(u10_df, v10_df)

# %%
wind_df=pd.merge(u10_df,v10_df)
wind_df
# Out:
#               time  latitude  longitude       u10       v10
# 0       1981-03-01     26.00      88.50  4.935639  0.746331
# 1       1981-03-01     26.00      89.75  3.125891  3.137681
# 2       1981-03-01     26.00      91.00  3.617355  3.682035
# 3       1981-03-01     26.00      92.25  3.407431  2.158481
# 4       1981-03-01     24.75      88.50  1.543232  0.937359
# ...            ...       ...        ...       ...       ...
# 205795  2022-10-31     22.25      92.25  0.186298 -0.946570
# 205796  2022-10-31     21.00      88.50 -0.896101 -4.201827
# 205797  2022-10-31     21.00      89.75 -0.123198 -3.573307
# 205798  2022-10-31     21.00      91.00  0.690809 -4.013993
# 205799  2022-10-31     21.00      92.25  0.500116 -2.048487
#
# [205800 rows x 5 columns]

# %%
# Assuming df is your DataFrame with columns 'u10' and 'v10'
wind_df['wind_speed'] = np.sqrt(wind_df['u10']**2 + wind_df['v10']**2)
wind_df=wind_df.drop(['u10','v10'],axis=1)
wind_df
# Out:
#               time  latitude  longitude  wind_speed
# 0       1981-03-01     26.00      88.50    4.991748
# 1       1981-03-01     26.00      89.75    4.429023
# 2       1981-03-01     26.00      91.00    5.161651
# 3       1981-03-01     26.00      92.25    4.033563
# 4       1981-03-01     24.75      88.50    1.805605
# ...            ...       ...        ...         ...
# 205795  2022-10-31     22.25      92.25    0.964729
# 205796  2022-10-31     21.00      88.50    4.296318
# 205797  2022-10-31     21.00      89.75    3.575430
# 205798  2022-10-31     21.00      91.00    4.073004
# 205799  2022-10-31     21.00      92.25    2.108653
#
# [205800 rows x 4 columns]

# %% [markdown]
# # precp

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.tp.resample(time='D').sum() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        

        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/precp csv/tp.{filename[10:-3]}.csv',index=False)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /10u,10v,precp/precp csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
tp_df = pd.concat(dfs, ignore_index=True)


tp_df
# csv_files
# Out:
#               time  latitude  longitude        tp
# 0       1981-03-01     26.00      88.50  0.000000
# 1       1981-03-01     26.00      89.75  0.000050
# 2       1981-03-01     26.00      91.00  0.000000
# 3       1981-03-01     26.00      92.25  0.000407
# 4       1981-03-01     24.75      88.50  0.000000
# ...            ...       ...        ...       ...
# 205795  2022-10-31     22.25      92.25  0.000229
# 205796  2022-10-31     21.00      88.50  0.000000
# 205797  2022-10-31     21.00      89.75  0.000000
# 205798  2022-10-31     21.00      91.00  0.000000
# 205799  2022-10-31     21.00      92.25  0.000126
#
# [205800 rows x 4 columns]

# %% [markdown]
# # MSLP

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres/mslp_spres.1981.nc')
ds.sp
# Out:
# <xarray.DataArray 'sp' (time: 8760, latitude: 33, longitude: 29)>
# [8383320 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Attributes:
#     units:          Pa
#     long_name:      Surface pressure
#     standard_name:  surface_air_pressure

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.msl.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres/mlsp csv/mslp.{filename[11:-3]}.csv',index=False)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres/mlsp csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
mslp_df = pd.concat(dfs, ignore_index=True)


mslp_df
# csv_files
# Out:
#               time  latitude  longitude         msl
# 0       1981-03-01     26.00      88.50  100962.040
# 1       1981-03-01     26.00      89.75  100963.305
# 2       1981-03-01     26.00      91.00  100945.710
# 3       1981-03-01     26.00      92.25  100959.690
# 4       1981-03-01     24.75      88.50  101059.695
# ...            ...       ...        ...         ...
# 205795  2022-10-31     22.25      92.25  101159.870
# 205796  2022-10-31     21.00      88.50  101202.020
# 205797  2022-10-31     21.00      89.75  101178.070
# 205798  2022-10-31     21.00      91.00  101144.900
# 205799  2022-10-31     21.00      92.25  101115.520
#
# [205800 rows x 4 columns]

# %% [markdown]
# # Surface pressure

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.sp.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        
     
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres/sp csv/sp.{filename[10:-3]}.csv',index=False)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /mlsp,surface pres/sp csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
sp_df = pd.concat(dfs, ignore_index=True)


sp_df
# csv_files
# Out:
#               time  latitude  longitude          sp
# 0       1981-03-01     26.00      88.50  100353.730
# 1       1981-03-01     26.00      89.75  100626.190
# 2       1981-03-01     26.00      91.00   99640.805
# 3       1981-03-01     26.00      92.25   96572.030
# 4       1981-03-01     24.75      88.50  100724.370
# ...            ...       ...        ...         ...
# 205795  2022-10-31     22.25      92.25   99555.770
# 205796  2022-10-31     21.00      88.50  101189.414
# 205797  2022-10-31     21.00      89.75  101177.780
# 205798  2022-10-31     21.00      91.00  101170.400
# 205799  2022-10-31     21.00      92.25  100762.120
#
# [205800 rows x 4 columns]

# %% [markdown]
# # VSWL1

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL/vswl-1&2.1981.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 29, latitude: 33, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Data variables:
#     swvl1      (time, latitude, longitude) float32 ...
#     swvl2      (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-09-30 22:45:45 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.swvl1.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        

        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL/vswl-1/vswl-1.{filename[9:-3]}.csv',index=False)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL/vswl-1/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
vswl_1_df = pd.concat(dfs, ignore_index=True)


vswl_1_df
# csv_files
# Out:
#               time  latitude  longitude     swvl1
# 0       1981-03-01     26.00      88.50  0.137547
# 1       1981-03-01     26.00      89.75  0.122477
# 2       1981-03-01     26.00      91.00  0.254968
# 3       1981-03-01     26.00      92.25  0.256408
# 4       1981-03-01     24.75      88.50  0.147519
# ...            ...       ...        ...       ...
# 205795  2022-10-31     22.25      92.25  0.335644
# 205796  2022-10-31     21.00      88.50 -0.000001
# 205797  2022-10-31     21.00      89.75 -0.000001
# 205798  2022-10-31     21.00      91.00 -0.000001
# 205799  2022-10-31     21.00      92.25  0.189271
#
# [205800 rows x 4 columns]

# %% [markdown]
# # VSWL2

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.swvl2.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        

        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL/vswl-2/vswl-2.{filename[9:-3]}.csv',index=False)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /VSWL/vswl-2/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
vswl_2_df = pd.concat(dfs, ignore_index=True)


vswl_2_df
# csv_files
# Out:
#               time  latitude  longitude     swvl2
# 0       1981-03-01     26.00      88.50  0.141404
# 1       1981-03-01     26.00      89.75  0.139678
# 2       1981-03-01     26.00      91.00  0.284444
# 3       1981-03-01     26.00      92.25  0.292251
# 4       1981-03-01     24.75      88.50  0.195994
# ...            ...       ...        ...       ...
# 205795  2022-10-31     22.25      92.25  0.347227
# 205796  2022-10-31     21.00      88.50  0.000002
# 205797  2022-10-31     21.00      89.75  0.000002
# 205798  2022-10-31     21.00      91.00  0.000002
# 205799  2022-10-31     21.00      92.25  0.199723
#
# [205800 rows x 4 columns]

# %% [markdown]
# # geopotential height

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Geopotential/geo_hgt.1981.nc')
ds.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:    (longitude: 29, latitude: 33, level: 3, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * level      (level) int32 500 850 1000
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Data variables:
#     z          (time, level, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-09-30 04:20:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...>

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Geopotential/'

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.z.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        

        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        dfs=[]
        for level in [1000, 850, 500]:
            #change
            data_level = resized_ds.sel(level=level).to_dataframe()

            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'z': f'geo_hgt_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Geopotential/csv files/{filename[:-3]}.csv',index=False)
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Geopotential/csv files/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
geo_hgt_df = pd.concat(dfs, ignore_index=True)


geo_hgt_df
# csv_files
# Out:
#               time  latitude  longitude  geo_hgt_1000hpa  geo_hgt_850hpa  \
# 0       1981-03-01     26.00      88.50        827.77374       14655.341
# 1       1981-03-01     26.00      89.75        820.29760       14633.402
# 2       1981-03-01     26.00      91.00        813.19775       14612.438
# 3       1981-03-01     26.00      92.25        830.85425       14577.802
# 4       1981-03-01     24.75      88.50        905.57477       14783.031
# ...            ...       ...        ...              ...             ...
# 205795  2022-10-31     22.25      92.25        983.78320       14945.448
# 205796  2022-10-31     21.00      88.50       1041.39880       14928.231
# 205797  2022-10-31     21.00      89.75       1019.68040       14935.509
# 205798  2022-10-31     21.00      91.00        992.48553       14935.284
# 205799  2022-10-31     21.00      92.25        957.90094       14929.206
#
#         geo_hgt_500hpa
# 0            56358.145
# 1            56294.090
# ...

# %% [markdown]
# # Relative humidity

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /rhum/rhum.1981.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 29, latitude: 33, level: 3, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * level      (level) int32 500 850 1000
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Data variables:
#     r          (time, level, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-09-30 09:30:51 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
#change
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /rhum/'

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.r.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        

        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        dfs=[]
        for level in [1000, 850, 500]:
            data_level = resized_ds.sel(level=level).to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'r': f'rhum_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /rhum/rhum csv/{filename[:-3]}.csv',index=False)
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /rhum/rhum csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
rhum_df = pd.concat(dfs, ignore_index=True)


rhum_df
# csv_files
# Out:
#               time  latitude  longitude  rhum_1000hpa  rhum_850hpa  \
# 0       1981-03-01     26.00      88.50     31.739103    37.990530
# 1       1981-03-01     26.00      89.75     45.348827    41.261345
# 2       1981-03-01     26.00      91.00     44.530594    44.800830
# 3       1981-03-01     26.00      92.25     45.894886    47.711990
# 4       1981-03-01     24.75      88.50     38.293460    41.798350
# ...            ...       ...        ...           ...          ...
# 205795  2022-10-31     22.25      92.25     83.600945    69.116400
# 205796  2022-10-31     21.00      88.50     65.116730    71.036720
# 205797  2022-10-31     21.00      89.75     70.810510    70.630830
# 205798  2022-10-31     21.00      91.00     75.589800    64.227196
# 205799  2022-10-31     21.00      92.25     82.296120    72.209150
#
#         rhum_500hpa
# 0         25.467537
# 1         26.321848
# 2         23.628645
# 3         21.382418
# 4         22.951593
# ...             ...
# ...

# %% [markdown]
# # Specific Humidity

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /shum/shum.1981.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 29, latitude: 33, level: 3, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * level      (level) int32 500 850 1000
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Data variables:
#     q          (time, level, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-09-29 15:41:52 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
#change
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /shum/'

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.q.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        

        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        dfs=[]
        for level in [1000, 850, 500]:
            data_level = resized_ds.sel(level=level).to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'q': f'shum_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /shum/Shum csv/{filename[:-3]}.csv',index=False)
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /shum/Shum csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
shum_df = pd.concat(dfs, ignore_index=True)


shum_df
# csv_files
# Out:
#               time  latitude  longitude  shum_1000hpa  shum_850hpa  \
# 0       1981-03-01     26.00      88.50      0.006488     0.005184
# 1       1981-03-01     26.00      89.75      0.008332     0.005631
# 2       1981-03-01     26.00      91.00      0.008821     0.005966
# 3       1981-03-01     26.00      92.25      0.008432     0.006218
# 4       1981-03-01     24.75      88.50      0.008196     0.006091
# ...            ...       ...        ...           ...          ...
# 205795  2022-10-31     22.25      92.25      0.018082     0.011400
# 205796  2022-10-31     21.00      88.50      0.014546     0.011246
# 205797  2022-10-31     21.00      89.75      0.015720     0.011311
# 205798  2022-10-31     21.00      91.00      0.017005     0.010577
# 205799  2022-10-31     21.00      92.25      0.018853     0.011916
#
#         shum_500hpa
# 0          0.000562
# 1          0.000583
# 2          0.000548
# 3          0.000511
# 4          0.000545
# ...             ...
# ...

# %% [markdown]
# # Tmeperature Level data

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Temperature multile level/temp_level.1981.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 29, latitude: 33, level: 3, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * level      (level) int32 500 850 1000
#   * time       (time) datetime64[ns] 1981-01-01 ... 1981-12-31T23:00:00
# Data variables:
#     t          (time, level, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-10-01 03:04:57 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
#change
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Temperature multile level/'

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.t.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        dfs=[]
        for level in [1000, 850, 500]:
            data_level = resized_ds.sel(level=level).to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'t': f'temp_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Temperature multile level/temp_level_csv/{filename[:-3]}.csv',index=False)
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Temperature multile level/temp_level_csv/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
temp_level_df = pd.concat(dfs, ignore_index=True)


temp_level_df
# csv_files
# Out:
#               time  latitude  longitude  temp_1000hpa  temp_850hpa  \
# 0       1981-03-01     26.00      88.50     299.42700    289.84842
# 1       1981-03-01     26.00      89.75     298.73923    289.71902
# 2       1981-03-01     26.00      91.00     299.59717    289.45248
# 3       1981-03-01     26.00      92.25     299.69824    289.52450
# 4       1981-03-01     24.75      88.50     300.28128    290.59137
# ...            ...       ...        ...           ...          ...
# 205795  2022-10-31     22.25      92.25     300.60910    292.84235
# 205796  2022-10-31     21.00      88.50     300.17850    291.81558
# 205797  2022-10-31     21.00      89.75     300.02487    292.00287
# 205798  2022-10-31     21.00      91.00     300.23416    292.42203
# 205799  2022-10-31     21.00      92.25     300.61264    292.48038
#
#         temp_500hpa
# 0         258.69492
# 1         258.60930
# 2         259.30600
# 3         259.83557
# 4         259.60406
# ...             ...
# ...

# %% [markdown]
# # Dew Point Temperature

# %%
ds=xr.open_dataset('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /2m Dew temp/dew_2m.2021.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 29, latitude: 33, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 86.0 86.25 86.5 86.75 ... 92.5 92.75 93.0
#   * latitude   (latitude) float32 28.0 27.75 27.5 27.25 ... 20.5 20.25 20.0
#   * time       (time) datetime64[ns] 2021-01-01 ... 2021-12-31T23:00:00
# Data variables:
#     d2m        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-10-06 22:32:55 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /2m Dew temp'
#change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        ds_daily = ds.d2m.resample(time='D').mean() #change 
        ds_daily = ds_daily.sel(time=(ds_daily['time.month'] >= 3) & (ds_daily['time.month'] <= 10))
        new_lat = np.arange(26,20.26, -1.25).astype(np.float32)
        new_lon = np.arange(88.50,92.76, 1.25).astype(np.float32)
        resized_ds = ds_daily.interp(latitude=new_lat, longitude=new_lon)
        df = resized_ds.to_dataframe()
        df=df.reset_index()
        #change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /2m Dew temp/csv files/{filename[:-3]}.csv',index=False)
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
#change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /2m Dew temp/csv files/*.csv')
csv_files.sort()
# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
#change
d2m_df = pd.concat(dfs, ignore_index=True)


d2m_df
# csv_files
# Out:
#               time  latitude  longitude        d2m
# 0       1981-03-01     26.00      88.50  281.59110
# 1       1981-03-01     26.00      89.75  283.25125
# 2       1981-03-01     26.00      91.00  284.63406
# 3       1981-03-01     26.00      92.25  284.76724
# 4       1981-03-01     24.75      88.50  285.80338
# ...            ...       ...        ...        ...
# 205795  2022-10-31     22.25      92.25  298.17505
# 205796  2022-10-31     21.00      88.50  294.27512
# 205797  2022-10-31     21.00      89.75  295.32272
# 205798  2022-10-31     21.00      91.00  296.57670
# 205799  2022-10-31     21.00      92.25  298.66006
#
# [205800 rows x 4 columns]

# %%
# sanjid

# %% [markdown]
# # Heat Index

# %% [markdown]
# https://www.weather.gov/epz/wxcalc_vaporpressure
# https://www.wikiwand.com/en/Vapour_pressure_of_water
# https://earthscience.stackexchange.com/questions/24156/era5-single-level-calculate-relative-humidity#:~:text=where%20Td%20is%20the,H%3De%2Fes
# https://atoc.colorado.edu/~cassano/wx_calculator/vaporpressure.html
# https://atoc.colorado.edu/~cassano/wx_calculator/wxcalc.html
# https://www.wpc.ncep.noaa.gov/html/heatindex_equation.shtml
# https://www.wpc.ncep.noaa.gov/html/heatindex.shtml

# %%
def rhum_2m_calculation(t2m,d2m):
    
    t2m_in_celcelsius=t2m-273.15
    d2m_in_celcelsius=d2m-273.15
    exponent_svp=(7.5*t2m_in_celcelsius)/(237.3+t2m_in_celcelsius)
    exponent_avp=(7.5*d2m_in_celcelsius)/(237.3+d2m_in_celcelsius)
    svp=6.11*10**exponent_svp
    avp=6.11*10**exponent_avp
    rhum_2m=(avp/svp)*100
    return rhum_2m
    
    
# heat_index(315,305)

# %%
def heat_index(t2m_kelvin, rh_percentage):
    
    t_fahrenheit = (t2m_kelvin-273.15) * 9/5 + 32 
    
    # Rothfusz regression equation
    heat_index = -42.379 + 2.04901523*t_fahrenheit + 10.14333127*rh_percentage - \
                 0.22475541*t_fahrenheit*rh_percentage - 0.00683783*t_fahrenheit**2 - \
                 0.05481717*rh_percentage**2 + 0.00122874*t_fahrenheit**2*rh_percentage + \
                 0.00085282*t_fahrenheit*rh_percentage**2 - 0.00000199*t_fahrenheit**2*rh_percentage**2
    
    # Apply adjustments
    if rh_percentage < 13 and 80 <= t_fahrenheit <= 112:
        adjustment = ((13 - rh_percentage) / 4) * math.sqrt((17 - abs(t_fahrenheit - 95)) / 17)
        heat_index -= adjustment
    
    if rh_percentage > 85 and 80 <= t_fahrenheit <= 87:
        adjustment = ((rh_percentage - 85) / 10) * ((87 - t_fahrenheit) / 5)
        heat_index += adjustment
    heat_index=(heat_index-32)*5/9+273.15
    
    return heat_index

# %%
import math

def heat_index(T, RH):
    T = (T-273.15) * 9/5 + 32 # converting calvin to farenheit.
    
    # Rothfusz regression equation
    HI = -42.379 + 2.04901523*T + 10.14333127*RH - 0.22475541*T*RH - 0.00683783*T**2 - \
         0.05481717*RH**2 + 0.00122874*T**2*RH + 0.00085282*T*RH**2 - 0.00000199*T**2*RH**2
    
    # Adjustments
    if RH < 13 and 80 <= T <= 112:
        ADJUSTMENT = ((13 - RH) / 4) * math.sqrt((17 - abs(T - 95)) / 17)
        HI -= ADJUSTMENT
    
    if RH > 85 and 80 <= T <= 87:
        ADJUSTMENT = ((RH - 85) / 10) * ((87 - T) / 5)
        HI += ADJUSTMENT
    
    # Check if Rothfusz regression is not appropriate
    if HI < 80:
        # Apply simpler formula
        HI = 0.5 * (T + 61.0 + ((T - 68.0) * 1.2) + (RH * 0.094))
    
    return HI

# %%
dfs=[t2m_df,mx2t_df,mn2t_df,d2m_df]
# Initialize the merged_df with the first DataFrame in the list
HI_df = dfs[0]

# Loop through the remaining DataFrames and merge them one by one
for df in dfs[1:]:
    HI_df = pd.merge(HI_df, df)
HI_df
# Out:
#               time  latitude  longitude        t2m       mx2t       mn2t  \
# 0       1981-03-01     26.00      88.50  300.10745  306.62286  292.43830
# 1       1981-03-01     26.00      89.75  300.12964  306.91562  292.82672
# 2       1981-03-01     26.00      91.00  300.21990  304.94385  294.69223
# 3       1981-03-01     26.00      92.25  298.27060  303.35596  292.18810
# 4       1981-03-01     24.75      88.50  298.44992  306.27887  292.41772
# ...            ...       ...        ...        ...        ...        ...
# 205795  2022-10-31     22.25      92.25  301.38754  304.44520  296.35650
# 205796  2022-10-31     21.00      88.50  301.09260  301.87408  300.35898
# 205797  2022-10-31     21.00      89.75  300.95898  301.36470  300.61063
# 205798  2022-10-31     21.00      91.00  301.19010  301.56662  300.68450
# 205799  2022-10-31     21.00      92.25  301.51074  303.90482  298.59036
#
#               d2m
# 0       281.59110
# 1       283.25125
# 2       284.63406
# ...

# %%
# HI_df["mx2t"][HI_df['mx2t'] < 299].count()

# %%
# HI_df['rhum_2m'] = HI_df.apply(lambda row: rhum_2m_calculation(row['t2m'], row['d2m']), axis=1)
# HI_df

# %%
HI_df['rhum_2m'] = HI_df.apply(lambda row: rhum_2m_calculation(row['t2m'], row['d2m']), axis=1)
HI_df['HI_max'] = HI_df.apply(lambda row: heat_index(row['mx2t'], row['rhum_2m']), axis=1)
HI_df['HI_min'] = HI_df.apply(lambda row: heat_index(row['mn2t'], row['rhum_2m']), axis=1)
HI_df
# Out:
#               time  latitude  longitude        t2m       mx2t       mn2t  \
# 0       1981-03-01     26.00      88.50  300.10745  306.62286  292.43830
# 1       1981-03-01     26.00      89.75  300.12964  306.91562  292.82672
# 2       1981-03-01     26.00      91.00  300.21990  304.94385  294.69223
# 3       1981-03-01     26.00      92.25  298.27060  303.35596  292.18810
# 4       1981-03-01     24.75      88.50  298.44992  306.27887  292.41772
# ...            ...       ...        ...        ...        ...        ...
# 205795  2022-10-31     22.25      92.25  301.38754  304.44520  296.35650
# 205796  2022-10-31     21.00      88.50  301.09260  301.87408  300.35898
# 205797  2022-10-31     21.00      89.75  300.95898  301.36470  300.61063
# 205798  2022-10-31     21.00      91.00  301.19010  301.56662  300.68450
# 205799  2022-10-31     21.00      92.25  301.51074  303.90482  298.59036
#
#               d2m    rhum_2m      HI_max     HI_min
# ...

# %%
# HI_df.info()

# %%
HI_df['HI_max'].describe(percentiles=[.5,.75,.90,.95])
# Out:
# count    205800.000000
# mean        102.482676
# std          11.829896
# min          67.950588
# 50%         101.557081
# 75%         110.477692
# 90%         117.644519
# 95%         122.462988
# max         163.878864
# Name: HI_max, dtype: float64

# %%
HI_df['HI_min'].describe(percentiles=[.5,.75,.90,.95])
# Out:
# count    205800.000000
# mean         78.330944
# std           6.909329
# min          53.844150
# 50%          78.305996
# 75%          82.425600
# 90%          87.099962
# 95%          89.615904
# max         110.283809
# Name: HI_min, dtype: float64

# %%
HI_df=HI_df.drop(['d2m','rhum_2m','t2m','mx2t','mn2t'],axis=1)

# %%
HI_df
# Out:
#               time  latitude  longitude      HI_max     HI_min
# 0       1981-03-01     26.00      88.50   90.984364  64.551763
# 1       1981-03-01     26.00      89.75   92.922277  65.491689
# 2       1981-03-01     26.00      91.00   88.943168  69.333321
# 3       1981-03-01     26.00      92.25   86.527588  64.610009
# 4       1981-03-01     24.75      88.50   95.505364  65.184065
# ...            ...       ...        ...         ...        ...
# 205795  2022-10-31     22.25      92.25  109.295286  74.739485
# 205796  2022-10-31     21.00      88.50   88.806258  84.016642
# 205797  2022-10-31     21.00      89.75   88.344764  85.669012
# 205798  2022-10-31     21.00      91.00   90.465675  86.876345
# 205799  2022-10-31     21.00      92.25  106.990427  79.247769
#
# [205800 rows x 5 columns]

# %%
import math

def heat_index(T, RH):
    # Rothfusz regression equation
    HI = -42.379 + 2.04901523*T + 10.14333127*RH - 0.22475541*T*RH - 0.00683783*T**2 - \
         0.05481717*RH**2 + 0.00122874*T**2*RH + 0.00085282*T*RH**2 - 0.00000199*T**2*RH**2
    
    # Adjustments
    if RH < 13 and 80 <= T <= 112:
        ADJUSTMENT = ((13 - RH) / 4) * math.sqrt((17 - abs(T - 95)) / 17)
        HI -= ADJUSTMENT
    
    if RH > 85 and 80 <= T <= 87:
        ADJUSTMENT = ((RH - 85) / 10) * ((87 - T) / 5)
        HI += ADJUSTMENT
    
    # Check if Rothfusz regression is not appropriate
    if HI < 80:
        # Apply simpler formula
        HI = 0.5 * (T + 61.0 + ((T - 68.0) * 1.2) + (RH * 0.094))
    
    return HI

# %%
# heat_index(90,75)

# %% [markdown]
# # Merged df

# %%
# t2m_df,mx2t_df,mn2t_df,u10_df,v10_df,tp_df,sp_df,geo_hgt_df,rhum_df,shum_dfmslp_df,vswl_1_df,vswl_2_df,

# %%
dfs=[t2m_df,mx2t_df,mn2t_df,HI_df,rhum_df,wind_df,tp_df,sp_df,geo_hgt_df,shum_df,mslp_df,vswl_1_df,vswl_2_df,temp_level_df]
# Initialize the merged_df with the first DataFrame in the list
merged_df = dfs[0]

# Loop through the remaining DataFrames and merge them one by one
for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df)

# Now merged_df contains the merged result
merged_df.to_csv('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/ERA 5 /Preprocessed data/merged_df_v1.csv',index=False)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205800 entries, 0 to 205799
# Data columns (total 26 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             205800 non-null  object
#  1   latitude         205800 non-null  float64
#  2   longitude        205800 non-null  float64
#  3   t2m              205800 non-null  float64
#  4   mx2t             205800 non-null  float64
#  5   mn2t             205800 non-null  float64
#  6   HI_max           205800 non-null  float64
#  7   HI_min           205800 non-null  float64
#  8   rhum_1000hpa     205800 non-null  float64
#  9   rhum_850hpa      205800 non-null  float64
#  10  rhum_500hpa      205800 non-null  float64
#  11  wind_speed       205800 non-null  float64
#  12  tp               205800 non-null  float64
#  13  sp               205800 non-null  float64
#  14  geo_hgt_1000hpa  205800 non-null  float64
#  15  geo_hgt_850hpa   205800 non-null  float64
# ...
