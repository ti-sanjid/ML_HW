# %%
import  xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import warnings

# %% [markdown]
# # Air Temperature

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Air temperature/'

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.air.to_dataframe()
        df=df.reset_index()
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Air temperature/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Air temperature/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
t2m_df = pd.concat(dfs, ignore_index=True)
t2m_df=t2m_df.drop('Unnamed: 0', axis=1)

t2m_df
# Out:
#              time   lat   lon        air
# 0      1996-01-01  25.0  90.0  287.91016
# 1      1996-01-01  25.0  92.5  286.24176
# 2      1996-01-01  22.5  90.0  294.35107
# 3      1996-01-01  22.5  92.5  289.19794
# 4      1996-01-02  25.0  90.0  288.65900
# ...           ...   ...   ...        ...
# 61355  2022-12-30  22.5  92.5  285.86066
# 61356  2022-12-31  25.0  90.0  285.81174
# 61357  2022-12-31  25.0  92.5  285.01230
# 61358  2022-12-31  22.5  90.0  292.70038
# 61359  2022-12-31  22.5  92.5  285.88900
#
# [61360 rows x 4 columns]

# %% [markdown]
# # Maximum Temperature

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Maximum Temperature/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.tmax.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Maximum Temperature/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Maximum Temperature/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
tmax_df = pd.concat(dfs, ignore_index=True) # change
tmax_df=tmax_df.drop('Unnamed: 0', axis=1)

tmax_df   # change
# Out:
#              time   lat   lon       tmax
# 0      1996-01-01  25.0  90.0  297.60540
# 1      1996-01-01  25.0  92.5  297.01794
# 2      1996-01-01  22.5  90.0  298.71228
# 3      1996-01-01  22.5  92.5  300.69077
# 4      1996-01-02  25.0  90.0  298.77374
# ...           ...   ...   ...        ...
# 61355  2022-12-30  22.5  92.5  297.28740
# 61356  2022-12-31  25.0  90.0  295.73610
# 61357  2022-12-31  25.0  92.5  295.29507
# 61358  2022-12-31  22.5  90.0  298.03186
# 61359  2022-12-31  22.5  92.5  297.45840
#
# [61360 rows x 4 columns]

# %% [markdown]
# # Minimum Temperature

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Minimum Temperature/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.tmin.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Minimum Temperature/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Minimum Temperature/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
tmin_df = pd.concat(dfs, ignore_index=True) # change
tmin_df=tmin_df.drop('Unnamed: 0', axis=1)

tmin_df   # change
# Out:
#              time   lat   lon       tmin
# 0      1996-01-01  25.0  90.0  281.89252
# 1      1996-01-01  25.0  92.5  279.16528
# 2      1996-01-01  22.5  90.0  289.81770
# 3      1996-01-01  22.5  92.5  280.41330
# 4      1996-01-02  25.0  90.0  281.91138
# ...           ...   ...   ...        ...
# 61355  2022-12-30  22.5  92.5  275.80807
# 61356  2022-12-31  25.0  90.0  276.47375
# 61357  2022-12-31  25.0  92.5  275.02954
# 61358  2022-12-31  22.5  90.0  288.64160
# 61359  2022-12-31  22.5  92.5  275.03717
#
# [61360 rows x 4 columns]

# %% [markdown]
# # Surface Pressure

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Surface Pressure-NCAR/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.pres.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Surface Pressure-NCAR/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Surface Pressure-NCAR/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
surface_pressure_df = pd.concat(dfs, ignore_index=True) # change
surface_pressure_df=surface_pressure_df.drop('Unnamed: 0', axis=1)

surface_pressure_df   # change
# Out:
#              time   lat   lon      pres
# 0      1997-01-01  25.0  90.0  100850.0
# 1      1997-01-01  25.0  92.5   97000.0
# 2      1997-01-01  22.5  90.0  102150.0
# 3      1997-01-01  22.5  92.5   96190.0
# 4      1997-01-02  25.0  90.0  100660.0
# ...           ...   ...   ...       ...
# 61355  2022-12-30  22.5  92.5   96225.0
# 61356  2022-12-31  25.0  90.0  100815.0
# 61357  2022-12-31  25.0  92.5   96885.0
# 61358  2022-12-31  22.5  90.0  102212.5
# 61359  2022-12-31  22.5  92.5   96197.5
#
# [61360 rows x 4 columns]

# %% [markdown]
# # Sea Level Pressure

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Sea level pressure/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.slp.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Sea level pressure/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Sea level pressure/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
slp_df = pd.concat(dfs, ignore_index=True) # change
slp_df=slp_df.drop('Unnamed: 0', axis=1)

slp_df   # change
# Out:
#              time   lat   lon       slp
# 0      1998-01-01  25.0  90.0  101970.0
# 1      1998-01-01  25.0  92.5  101975.0
# 2      1998-01-01  22.5  90.0  101732.0
# 3      1998-01-01  22.5  92.5  101692.0
# 4      1998-01-02  25.0  90.0  101925.0
# ...           ...   ...   ...       ...
# 61355  2022-12-30  22.5  92.5  101720.0
# 61356  2022-12-31  25.0  90.0  101907.5
# 61357  2022-12-31  25.0  92.5  101807.5
# 61358  2022-12-31  22.5  90.0  101722.5
# 61359  2022-12-31  22.5  92.5  101697.5
#
# [61360 rows x 4 columns]

# %% [markdown]
# # Precipitation

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Precipitation/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.prate.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Precipitation/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Precipitation/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
prate_df = pd.concat(dfs, ignore_index=True) # change
prate_df=prate_df.drop('Unnamed: 0', axis=1)

prate_df   # change
# Out:
#              time   lat   lon         prate
# 0      1995-01-01  25.0  90.0  2.425549e-06
# 1      1995-01-01  25.0  92.5  3.999374e-07
# 2      1995-01-01  22.5  90.0  1.624216e-07
# 3      1995-01-01  22.5  92.5  1.415758e-07
# 4      1995-01-02  25.0  90.0  2.100509e-06
# ...           ...   ...   ...           ...
# 61355  2022-12-30  22.5  92.5  0.000000e+00
# 61356  2022-12-31  25.0  90.0  1.094083e-06
# 61357  2022-12-31  25.0  92.5  2.083968e-07
# 61358  2022-12-31  22.5  90.0  0.000000e+00
# 61359  2022-12-31  22.5  92.5  0.000000e+00
#
# [61360 rows x 4 columns]

# %%
import pandas as pd

precp_df=prate_df

precp_df['daily_precp'] = precp_df['prate'] * 86400


precp_df
# Out:
#              time   lat   lon         prate  daily_precp
# 0      1995-01-01  25.0  90.0  2.425549e-06     0.209567
# 1      1995-01-01  25.0  92.5  3.999374e-07     0.034555
# 2      1995-01-01  22.5  90.0  1.624216e-07     0.014033
# 3      1995-01-01  22.5  92.5  1.415758e-07     0.012232
# 4      1995-01-02  25.0  90.0  2.100509e-06     0.181484
# ...           ...   ...   ...           ...          ...
# 61355  2022-12-30  22.5  92.5  0.000000e+00     0.000000
# 61356  2022-12-31  25.0  90.0  1.094083e-06     0.094529
# 61357  2022-12-31  25.0  92.5  2.083968e-07     0.018005
# 61358  2022-12-31  22.5  90.0  0.000000e+00     0.000000
# 61359  2022-12-31  22.5  92.5  0.000000e+00     0.000000
#
# [61360 rows x 5 columns]

# %% [markdown]
# # 10 m U

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/10m u/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.uwnd.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/10m u/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/10m u/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
uwind_df = pd.concat(dfs, ignore_index=True) # change
uwind_df=uwind_df.drop('Unnamed: 0', axis=1)

uwind_df   # change
# Out:
#              time   lat   lon      uwnd
# 0      1996-01-01  25.0  90.0 -0.582426
# 1      1996-01-01  25.0  92.5 -0.268723
# 2      1996-01-01  22.5  90.0 -0.991821
# 3      1996-01-01  22.5  92.5 -0.091114
# 4      1996-01-02  25.0  90.0 -1.251181
# ...           ...   ...   ...       ...
# 61355  2022-12-30  22.5  92.5  0.724410
# 61356  2022-12-31  25.0  90.0  0.112595
# 61357  2022-12-31  25.0  92.5  0.021775
# 61358  2022-12-31  22.5  90.0 -0.440561
# 61359  2022-12-31  22.5  92.5  0.619199
#
# [61360 rows x 4 columns]

# %% [markdown]
# # 10 m V

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/10m v/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        df = data_bangladesh_resized.vwnd.to_dataframe()# change
        df=df.reset_index()
        # change
        df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/10m v/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/10m v/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
vwind_df = pd.concat(dfs, ignore_index=True) # change
vwind_df=vwind_df.drop('Unnamed: 0', axis=1)

vwind_df   # change
# Out:
#              time   lat   lon      vwnd
# 0      1996-01-01  25.0  90.0 -1.388664
# 1      1996-01-01  25.0  92.5 -1.082961
# 2      1996-01-01  22.5  90.0 -2.103011
# 3      1996-01-01  22.5  92.5 -0.706727
# 4      1996-01-02  25.0  90.0 -1.815052
# ...           ...   ...   ...       ...
# 61355  2022-12-30  22.5  92.5 -0.445329
# 61356  2022-12-31  25.0  90.0  0.450114
# 61357  2022-12-31  25.0  92.5 -0.524987
# 61358  2022-12-31  22.5  90.0  0.349927
# 61359  2022-12-31  22.5  92.5 -0.412021
#
# [61360 rows x 4 columns]

# %% [markdown]
# # Geopotential Height

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Geopotential Height/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        dfs=[]
        for level in [1000, 850, 500]:
            #change
            data_level = data_bangladesh_resized.sel(level=level).hgt.to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'hgt': f'geo_hgt_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Geopotential Height/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Geopotential Height/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
geo_hgt_df = pd.concat(dfs, ignore_index=True) # change
geo_hgt_df=geo_hgt_df.drop('Unnamed: 0', axis=1)

geo_hgt_df   # change
# Out:
#              time   lat   lon  geo_hgt_1000hpa  geo_hgt_850hpa  geo_hgt_500hpa
# 0      1998-01-01  25.0  90.0           160.75         1532.25         5789.00
# 1      1998-01-01  25.0  92.5           167.50         1532.50         5791.25
# 2      1998-01-01  22.5  90.0           156.25         1536.75         5827.75
# 3      1998-01-01  22.5  92.5           157.00         1533.00         5830.50
# 4      1998-01-02  25.0  90.0           151.75         1518.50         5779.25
# ...           ...   ...   ...              ...             ...             ...
# 61355  2022-12-30  22.5  92.5           157.00         1532.25         5839.25
# 61356  2022-12-31  25.0  90.0           161.75         1530.25         5766.25
# 61357  2022-12-31  25.0  92.5           164.00         1531.00         5759.50
# 61358  2022-12-31  22.5  90.0           154.75         1531.00         5815.75
# 61359  2022-12-31  22.5  92.5           155.25         1530.25         5808.00
#
# [61360 rows x 6 columns]

# %% [markdown]
# # Relative Humidity

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Relative Humidity/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        dfs=[]
        for level in [1000, 850, 500]:
            #change
            data_level = data_bangladesh_resized.sel(level=level).rhum.to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'rhum': f'rhum_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Relative Humidity/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Relative Humidity/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
rhum_df = pd.concat(dfs, ignore_index=True) # change
rhum_df=rhum_df.drop('Unnamed: 0', axis=1)

rhum_df   # change
# Out:
#              time   lat   lon  rhum_1000hpa  rhum_850hpa  rhum_500hpa
# 0      1998-01-01  25.0  90.0     64.000015    42.000004         6.50
# 1      1998-01-01  25.0  92.5     67.750015    67.500015         4.25
# 2      1998-01-01  22.5  90.0     49.250008    27.000000         5.75
# 3      1998-01-01  22.5  92.5     62.000008    45.750008         8.75
# 4      1998-01-02  25.0  90.0     64.250015    36.000000        18.25
# ...           ...   ...   ...           ...          ...          ...
# 61355  2022-12-30  22.5  92.5     43.750000    28.000000        11.75
# 61356  2022-12-31  25.0  90.0     62.500000    56.500000         7.00
# 61357  2022-12-31  25.0  92.5     60.750000    63.000000         7.25
# 61358  2022-12-31  22.5  90.0     45.500000    36.250000         4.50
# 61359  2022-12-31  22.5  92.5     40.750000    32.000000         5.50
#
# [61360 rows x 6 columns]

# %% [markdown]
# # Air temperature Multiple levels

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Air temperature multiple levels/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        dfs=[]
        for level in [1000, 850, 500]:
            #change
            data_level = data_bangladesh_resized.sel(level=level).air.to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'air': f'air_temp_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Air temperature multiple levels/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Air temperature multiple levels/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
air_temp_df = pd.concat(dfs, ignore_index=True) # change
air_temp_df=air_temp_df.drop('Unnamed: 0', axis=1)

air_temp_df   # change
# Out:
#              time   lat   lon  air_temp_1000hpa  air_temp_850hpa  \
# 0      1998-01-01  25.0  90.0         291.87500        283.02500
# 1      1998-01-01  25.0  92.5         289.45000        282.02502
# 2      1998-01-01  22.5  90.0         293.37500        284.20000
# 3      1998-01-01  22.5  92.5         291.17502        283.80000
# 4      1998-01-02  25.0  90.0         290.67500        282.57500
# ...           ...   ...   ...               ...              ...
# 61355  2022-12-30  22.5  92.5         291.50000        283.75000
# 61356  2022-12-31  25.0  90.0         291.34998        282.12497
# 61357  2022-12-31  25.0  92.5         290.37500        282.27496
# 61358  2022-12-31  22.5  90.0         292.59998        284.32498
# 61359  2022-12-31  22.5  92.5         291.50000        284.39996
#
#        air_temp_500hpa
# 0            264.20000
# 1            264.35000
# 2            266.02502
# 3            265.97500
# 4            262.42502
# ...                ...
# 61355        267.52496
# 61356        263.47498
# 61357        263.12500
# 61358        266.82498
# 61359        266.65000
#
# [61360 rows x 6 columns]

# %% [markdown]
# # Specific Humidity

# %%
import os
from tqdm.auto import tqdm

# # Define the directory path
directory_path = '/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Specific Humidity Multiple levels/'# change

# Loop through all files in the directory
for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.nc'):  # Assuming you want to process only netcdf files
        file_path = os.path.join(directory_path, filename)
        # Process the file here
        ds = xr.open_dataset(file_path)
        new_lat = np.arange(90, -91, -02.5).astype(np.float32)
        new_lon = np.arange(0, 360, 02.5).astype(np.float32)
        new_ds = ds.interp(lat=new_lat, lon=new_lon)
        lat_range = slice(26.7,20.7) 
        lon_range = slice(88,92.7)
        data_bangladesh_resized = new_ds.sel(lat=lat_range,lon=lon_range)
        dfs=[]
        for level in [1000, 850, 500]:
            #change
            data_level = data_bangladesh_resized.sel(level=level).shum.to_dataframe()
            data_level = data_level.drop('level', axis=1)
            #change
            data_level = data_level.rename(columns={'shum': f'shum_{level}hpa'})
            data_level = data_level.reset_index()
            dfs.append(data_level)

        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df)
        # change
        merged_df.to_csv(f'/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Specific Humidity Multiple levels/csv files/{filename[:-3]}.csv')
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]

# %%
import pandas as pd
from glob import glob

# Get a list of all CSV files in the directory
# change
csv_files = glob('/mnt/1A42C1DD42C1BE2F/MyProjects/ML_HEATWAVE/Specific Humidity Multiple levels/csv files/*.csv')

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through the list of files
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into one
shum_df = pd.concat(dfs, ignore_index=True) # change
shum_df=shum_df.drop('Unnamed: 0', axis=1)
shum_df   # change
# Out:
#              time   lat   lon  shum_1000hpa  shum_850hpa  shum_500hpa
# 0      1998-01-01  25.0  90.0      0.008453     0.003735     0.000253
# 1      1998-01-01  25.0  92.5      0.007543     0.005595     0.000165
# 2      1998-01-01  22.5  90.0      0.007225     0.002543     0.000256
# 3      1998-01-01  22.5  92.5      0.007605     0.004298     0.000387
# 4      1998-01-02  25.0  90.0      0.007870     0.003125     0.000617
# ...           ...   ...   ...           ...          ...          ...
# 61355  2022-12-30  22.5  92.5      0.005520     0.002625     0.000588
# 61356  2022-12-31  25.0  90.0      0.008135     0.004732     0.000258
# 61357  2022-12-31  25.0  92.5      0.007278     0.005328     0.000258
# 61358  2022-12-31  22.5  90.0      0.006417     0.003502     0.000217
# 61359  2022-12-31  22.5  92.5      0.005177     0.003140     0.000262
#
# [61360 rows x 6 columns]

# %%
dfs=[t2m_df,tmax_df,tmin_df,surface_pressure_df,slp_df,precp_df,uwind_df, vwind_df,geo_hgt_df,rhum_df,air_temp_df,shum_df]
# Initialize the merged_df with the first DataFrame in the list
merged_df = dfs[0]

# Loop through the remaining DataFrames and merge them one by one
for df in dfs[1:]:
    merged_df = pd.merge(merged_df,
columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61360 entries, 0 to 61359
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              61360 non-null  object
#  1   lat               61360 non-null  float64
#  2   lon               61360 non-null  float64
#  3   air               61360 non-null  float64
#  4   tmax              61360 non-null  float64
#  5   tmin              61360 non-null  float64
#  6   pres              61360 non-null  float64
#  7   slp               61360 non-null  float64
#  8   prate             61360 non-null  float64
#  9   daily_precp       61360 non-null  float64
#  10  uwnd              61360 non-null  float64
#  11  vwnd              61360 non-null  float64
#  12  geo_hgt_1000hpa   61360 non-null  float64
#  13  geo_hgt_850hpa    61360 non-null  float64
#  14  geo_hgt_500hpa    61360 non-null  float64
#  15  rhum_1000hpa      61360 non-null  float64
#  16  rhum_850hpa       61360 non-null  float64
#  17  rhum_500hpa       61360 non-null  float64
#  18  air_temp_1000hpa  61360 non-null  float64
#  19  air_temp_850hpa   61360 non-null  float64
#  20  air_temp_500hpa   61360 non-null  float64
#  21  shum_1000hpa      61360 non-null  float64
#  22  shum_850hpa       61360 non-null  float64
#  23  shum_500hpa       61360 non-null  float64
# dtypes: float64(23), object(1)
# memory usage: 11.7+ MB

# %%
merged_df.set_index('time',inplace=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61360 entries, 1996-01-01 to 2022-12-31
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   lat               61360 non-null  float64
#  1   lon               61360 non-null  float64
#  2   air               61360 non-null  float64
#  3   tmax              61360 non-null  float64
#  4   tmin              61360 non-null  float64
#  5   pres              61360 non-null  float64
#  6   slp               61360 non-null  float64
#  7   prate             61360 non-null  float64
#  8   daily_precp       61360 non-null  float64
#  9   uwnd              61360 non-null  float64
#  10  vwnd              61360 non-null  float64
#  11  geo_hgt_1000hpa   61360 non-null  float64
#  12  geo_hgt_850hpa    61360 non-null  float64
#  13  geo_hgt_500hpa    61360 non-null  float64
#  14  rhum_1000hpa      61360 non-null  float64
#  15  rhum_850hpa       61360 non-null  float64
#  16  rhum_500hpa       61360 non-null  float64
#  17  air_temp_1000hpa  61360 non-null  float64
#  18  air_temp_850hpa   61360 non-null  float64
#  19  air_temp_500hpa   61360 non-null  float64
#  20  shum_1000hpa      61360 non-null  float64
#  21  shum_850hpa       61360 non-null  float64
#  22  shum_500hpa       61360 non-null  float64
# dtypes: float64(23)
# memory usage: 11.2+ MB

# %%
merged_df['tmax'].describe(percentiles=[.5,.75,.90,.95])
# Out:
# count    61360.000000
# mean       301.154367
# std          3.810131
# min        274.416500
# 50%        300.630160
# 75%        302.781700
# 90%        306.481320
# 95%        308.236734
# max        323.688230
# Name: tmax, dtype: float64

# %%
merged_df['tmin'].describe(percentiles=[.5,.75,.90,.95])
# Out:
# count    61360.000000
# mean       290.876644
# std          6.732665
# min        266.896030
# 50%        292.849315
# 75%        295.839420
# 90%        298.961550
# 95%        299.799700
# max        302.774630
# Name: tmin, dtype: float64

